# %%
from sqlalchemy import create_engine
import pymysql
import pandas as pd

# %%
db_connection_str = 'mysql+pymysql://deepanalytics:Sqltask1234!@34.73.222.197/deepanalytics'

# %%
db_connection = create_engine(db_connection_str)

# %%
datac2t1 = pd.read_sql('SELECT * FROM credit', con=db_connection)

# %%
datac2t1
# Out:
#       MyUnknownColumn         X1      X2           X3        X4   X5     X6  \
# 0                  ID  LIMIT_BAL     SEX    EDUCATION  MARRIAGE  AGE  PAY_0
# 1                   1      20000  female   university         1   24      2
# 2                   2     120000  female   university         2   26     -1
# 3                   3      90000  female   university         2   34      0
# 4                   4      50000  female   university         1   37      0
# ...               ...        ...     ...          ...       ...  ...    ...
# 30199           29996     220000    male  high school         1   39      0
# 30200           29997     150000    male  high school         2   43     -1
# 30201           29998      30000    male   university         2   37      4
# 30202           29999      80000    male  high school         1   41      1
# 30203           30000      50000    male   university         1   46      0
#
# ...

# %%
filename = 'Credit_One_a'
name_path = f"c:\\users\johne\Documents\Purdue DA\------How to Program\{filename}.csv"
datac2t1.to_csv(str(name_path))

# %%
#   READ DATA BACK IN FROM FILE 'b' AFTER CHANGING COLUMN LOCATION 1 TO 6, NOT 6 TO 1: PAY AND BILL AMOUNTS.
#    EASIER FOR ME TO READ

data = pd.read_csv( f"c:\\users\johne\Documents\Purdue DA\------How to Program\Credit_one_b.csv")
#data = data.drop_duplicates()
data
# Out:
#            0     ID LIMIT_BAL     SEX    EDUCATION MARRIAGE AGE PAY_1 PAY_2  \
# 0          1      1     20000  female   university        1  24     2     2
# 1          2      2    120000  female   university        2  26    -1     2
# 2          3      3     90000  female   university        2  34     0     0
# 3          4      4     50000  female   university        1  37     0     0
# 4          5      5     50000    male   university        1  57    -1     0
# ...      ...    ...       ...     ...          ...      ...  ..   ...   ...
# 30198  30199  29996    220000    male  high school        1  39     0     0
# 30199  30200  29997    150000    male  high school        2  43    -1    -1
# 30200  30201  29998     30000    male   university        2  37     4     3
# 30201  30202  29999     80000    male  high school        1  41     1    -1
# 30202  30203  30000     50000    male   university        1  46     0     0
#
# ...

# %%
#   FIND INDEX LOCATION OF ROW/AXIS THAT HAS  'NA'  DATA POINT
data[data['ID'].isnull()].index.tolist()
# Out:
# [201]

# %%
#   REMOVE INDEX 201 COMPLETELY, NOTICE 202 NOW HAS BAD DATA AS WELL.
data = data.drop(201)
print(data.iloc[198:208, :])
# Out:
#        0   ID  LIMIT_BAL     SEX        EDUCATION  MARRIAGE  AGE  PAY_1  \
# 198  199  199     500000  female  graduate school         1   34     -2
# 199  200  200      30000  female      high school         2   22      1
# 200  201  201     180000  female  graduate school         1   38     -2
# 202  203   ID  LIMIT_BAL     SEX        EDUCATION  MARRIAGE  AGE  PAY_0
# 203  204    1      20000  female       university         1   24      2
# 204  205    2     120000  female       university         2   26     -1
# 205  206    3      90000  female       university         2   34      0
# 206  207    4      50000  female       university         1   37      0
# 207  208    5      50000    male       university         1   57     -1
# 208  209    6      50000    male  graduate school         2   37      0
#
#      PAY_2  PAY_3  ...  BILL_AMT3  BILL_AMT2  BILL_AMT1  PAY_AMT6  PAY_AMT5  \
# 198     -2     -2  ...       2299        138        412     15816      1151
# ...

# %%
#    REMOVE AXIS 202 AND VERIFY DATA
# iNDEX 201 AND 202 MISSING: CAN WE RE-INDEX??????
data = data.drop(202)
print(data.iloc[198:208, :])
# Out:
#        0   ID LIMIT_BAL     SEX        EDUCATION MARRIAGE AGE PAY_1 PAY_2  \
# 198  199  199    500000  female  graduate school        1  34    -2    -2
# 199  200  200     30000  female      high school        2  22     1     2
# 200  201  201    180000  female  graduate school        1  38    -2    -2
# 203  204    1     20000  female       university        1  24     2     2
# 204  205    2    120000  female       university        2  26    -1     2
# 205  206    3     90000  female       university        2  34     0     0
# 206  207    4     50000  female       university        1  37     0     0
# 207  208    5     50000    male       university        1  57    -1     0
# 208  209    6     50000    male  graduate school        2  37     0     0
# 209  210    7    500000    male  graduate school        2  29     0     0
#
#     PAY_3  ... BILL_AMT3 BILL_AMT2 BILL_AMT1 PAY_AMT6 PAY_AMT5 PAY_AMT4  \
# 198    -2  ...      2299       138       412    15816     1151     1206
# ...

# %%
# Remove columns 0 and ID. They are redundant, offer nothing probative, are a duplicate index and prevent finding duplicates.
data = data.drop(['0', 'ID'], axis = 1)
data
# Out:
#       LIMIT_BAL     SEX    EDUCATION MARRIAGE AGE PAY_1 PAY_2 PAY_3 PAY_4  \
# 0         20000  female   university        1  24     2     2    -1    -1
# 1        120000  female   university        2  26    -1     2     0     0
# 2         90000  female   university        2  34     0     0     0     0
# 3         50000  female   university        1  37     0     0     0     0
# 4         50000    male   university        1  57    -1     0    -1     0
# ...         ...     ...          ...      ...  ..   ...   ...   ...   ...
# 30198    220000    male  high school        1  39     0     0     0     0
# 30199    150000    male  high school        2  43    -1    -1    -1    -1
# 30200     30000    male   university        2  37     4     3     2    -1
# 30201     80000    male  high school        1  41     1    -1     0     0
# 30202     50000    male   university        1  46     0     0     0     0
#
#       PAY_5  ... BILL_AMT3 BILL_AMT2 BILL_AMT1 PAY_AMT6 PAY_AMT5 PAY_AMT4  \
# ...

# %%
#Count number of cells that do not include 'NA,or NAN' in each column(axis = 0)
data.count(axis=0)
# Out:
# LIMIT_BAL                     30201
# SEX                           30201
# EDUCATION                     30201
# MARRIAGE                      30201
# AGE                           30201
# PAY_1                         30201
# PAY_2                         30201
# PAY_3                         30201
# PAY_4                         30201
# PAY_5                         30201
# PAY_6                         30201
# BILL_AMT6                     30201
# BILL_AMT5                     30201
# BILL_AMT4                     30201
# BILL_AMT3                     30201
# BILL_AMT2                     30201
# BILL_AMT1                     30201
# PAY_AMT6                      30201
# PAY_AMT5                      30201
# PAY_AMT4                      30201
# PAY_AMT3                      30201
# PAY_AMT2                      30201
# PAY_AMT1                      30201
# default payment next month    30201
# dtype: int64

# %%
# Remove duplicates now that 0 and ID columns have been removed.
data = data.drop_duplicates()
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 29965 entries, 0 to 30202
# Data columns (total 24 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   LIMIT_BAL                   29965 non-null  object
#  1   SEX                         29965 non-null  object
#  2   EDUCATION                   29965 non-null  object
#  3   MARRIAGE                    29965 non-null  object
#  4   AGE                         29965 non-null  object
#  5   PAY_1                       29965 non-null  object
#  6   PAY_2                       29965 non-null  object
#  7   PAY_3                       29965 non-null  object
#  8   PAY_4                       29965 non-null  object
#  9   PAY_5                       29965 non-null  object
#  10  PAY_6                       29965 non-null  object
#  11  BILL_AMT6                   29965 non-null  object
#  12  BILL_AMT5                   29965 non-null  object
# ...

# %%
# CREATE LIST WITH ALL COLUMN HEADINGS
# LOOP THROUGH LIST AND CONVERT EACH COLUMN TO NUMERIC. CAN DOWNGRADE IF WANT TO FLOAT.
# data2 defined to CLEAR DATA when running multiple changes 

data2 = pd.DataFrame()
header = ['LIMIT_BAL', 'EDUCATION', 'MARRIAGE', 'AGE', 'PAY_1' , 'PAY_2' , 'PAY_3' , 'PAY_4' , 'PAY_5' ,
          'PAY_6' , 'BILL_AMT6' , 'BILL_AMT5' , 'BILL_AMT4' , 'BILL_AMT3' , 'BILL_AMT2' , 
          'BILL_AMT1' , 'PAY_AMT6' , 'PAY_AMT5' , 'PAY_AMT4' , 'PAY_AMT3' , 'PAY_AMT2' , 'PAY_AMT1', 'default payment next month']
for i in range(len(header)):
    name = str(header[i])
    if name == "MARRIAGE" or name == 'EDUCATION' or name == 'default payment next month':
        data2.loc[:, name] = data.loc[:, name]
    else:
        data2.loc[:, name] = pd.to_numeric(data.loc[:, name])

    # THESE LINES WORKED, BUT WITH WARNINGS, AND TEDIOUS TO TYPE IN ALL COLUMN HEADINGS !!!!!
# data['MARRIAGE'] = pd.to_numeric(data['MARRIAGE'])
# data['MARRIAGE'] = data['MARRIAGE'].astype(int)
# data.loc[:, 'AGE'] = pd.to_numeric(data.loc[:, 'AGE'])
# data['PAY_1'] = pd.to_numeric(data['PAY_1'])
# data['PAY_2'] = pd.to_numeric(data['PAY_2'])
# data['PAY_3'] = pd.to_numeric(data['PAY_3'])
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 29965 entries, 0 to 30202
# Data columns (total 23 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   LIMIT_BAL                   29965 non-null  int64
#  1   EDUCATION                   29965 non-null  object
#  2   MARRIAGE                    29965 non-null  object
#  3   AGE                         29965 non-null  int64
#  4   PAY_1                       29965 non-null  int64
#  5   PAY_2                       29965 non-null  int64
#  6   PAY_3                       29965 non-null  int64
#  7   PAY_4                       29965 non-null  int64
#  8   PAY_5                       29965 non-null  int64
#  9   PAY_6                       29965 non-null  int64
#  10  BILL_AMT6                   29965 non-null  int64
#  11  BILL_AMT5                   29965 non-null  int64
#  12  BILL_AMT4                   29965 non-null  int64
# ...

# %%
data2
# Out:
#        LIMIT_BAL  MARRIAGE  AGE  PAY_1  PAY_2  PAY_3  PAY_4  PAY_5  PAY_6  \
# 0          20000         1   24      2      2     -1     -1     -2     -2
# 1         120000         2   26     -1      2      0      0      0      2
# 2          90000         2   34      0      0      0      0      0      0
# 3          50000         1   37      0      0      0      0      0      0
# 4          50000         1   57     -1      0     -1      0      0      0
# ...          ...       ...  ...    ...    ...    ...    ...    ...    ...
# 30198     220000         1   39      0      0      0      0      0      0
# 30199     150000         2   43     -1     -1     -1     -1      0      0
# 30200      30000         2   37      4      3      2     -1      0      0
# 30201      80000         1   41      1     -1      0      0      0     -1
# 30202      50000         1   46      0      0      0      0      0      0
#
#        BILL_AMT6  ...  BILL_AMT4  BILL_AMT3  BILL_AMT2  BILL_AMT1  PAY_AMT6  \
# ...

# %%
# RESET INDEX
#   "drop = True" drops the existing index

clean_data = data.reset_index(drop = True)
clean_data
# Out:
#        LIMIT_BAL     SEX    EDUCATION  MARRIAGE  AGE  PAY_1  PAY_2  PAY_3  \
# 0          20000  female   university         1   24      2      2     -1
# 1         120000  female   university         2   26     -1      2      0
# 2          90000  female   university         2   34      0      0      0
# 3          50000  female   university         1   37      0      0      0
# 4          50000    male   university         1   57     -1      0     -1
# ...          ...     ...          ...       ...  ...    ...    ...    ...
# 29960     220000    male  high school         1   39      0      0      0
# 29961     150000    male  high school         2   43     -1     -1     -1
# 29962      30000    male   university         2   37      4      3      2
# 29963      80000    male  high school         1   41      1     -1      0
# 29964      50000    male   university         1   46      0      0      0
#
#        PAY_4  PAY_5  ...  BILL_AMT3  BILL_AMT2  BILL_AMT1  PAY_AMT6  PAY_AMT5  \
# ...
